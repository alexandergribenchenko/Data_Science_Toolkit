# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/Data_Science_Toolkit/blob/main/HTML/DS_Email_01_Envio_HTML_(sin_attach).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prueba 02 (OK)

# %%
import pandas as pd

# %%
path_github = 'https://raw.githubusercontent.com/alexandergribenchenko/Data_Science_Datasets/main/Kaggle_Titanic/train.csv'

# %%
df = pd.read_csv(path_github, dtype=object, nrows=10)
df
# Out:
#   PassengerId Survived Pclass  \
# 0           1        0      3
# 1           2        1      1
# 2           3        1      3
# 3           4        1      1
# 4           5        0      3
# 5           6        0      3
# 6           7        0      1
# 7           8        0      3
# 8           9        1      3
# 9          10        1      2
#
#                                                 Name     Sex  Age SibSp Parch  \
# 0                            Braund, Mr. Owen Harris    male   22     1     0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38     1     0
# 2                             Heikkinen, Miss. Laina  female   26     0     0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35     1     0
# 4                           Allen, Mr. William Henry    male   35     0     0
# 5                                   Moran, Mr. James    male  NaN     0     0
# 6                            McCarthy, Mr. Timothy J    male   54     0     0
# ...

# %%
html_saludo="""<p>&nbsp;Hola!</p>

<p>😀</p>

<p><span style="color:#e74c3c"><strong>Estoy haciendo una prueba de envio.</strong></span></p>"""

# %%
html_tabla = df.to_html()

# %%
import os
import smtplib
import imghdr
from email.message import EmailMessage

# %%
EMAIL_ADDRESS = 'alexander.ortega@tcs.com'
EMAIL_PASSWORD = 'lufgqosokrhkpraz'

# %%
# contacts = ['alexander.ortega@tcs.com', 'alberto.lopez@avianca.com', 'catalina.lopez@dxc.com', 'catalina.lopez.subavh@avianca.com']
contacts = ['alexander.ortega@tcs.com']

msg = EmailMessage()
msg['Subject'] = 'Test Envio email 221028'
msg['From'] = EMAIL_ADDRESS
msg['To'] = contacts

msg.set_content('This is a plain text email')

# %%
msg.add_alternative(html_saludo + html_tabla, subtype='html')

# %%
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
    smtp.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
    smtp.send_message(msg)

# %% [markdown]
# # Prueba 01 (OK)

# %%
# import os
# import smtplib
# import imghdr
# from email.message import EmailMessage

# %%
# EMAIL_ADDRESS = 'alexander.ortega@tcs.com'
# EMAIL_PASSWORD = 'lufgqosokrhkpraz'

# # contacts = ['alexander.ortega@tcs.com', 'juan.motta@avianca.com']
# contacts = ['alexander.ortega@tcs.com']

# msg = EmailMessage()
# msg['Subject'] = 'Test Envio email 221028'
# msg['From'] = EMAIL_ADDRESS
# msg['To'] = contacts

# msg.set_content('This is a plain text email')

# msg.add_alternative("""\
# <!DOCTYPE html>
# <html>
#     <body>
#         <h1 style="color:SlateGray;">This is an HTML Email!</h1>
#     </body>
# </html>
# """, subtype='html')


# with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
#     smtp.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
#     smtp.send_message(msg)
